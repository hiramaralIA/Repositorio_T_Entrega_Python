# %% [markdown]
# <a href="https://colab.research.google.com/github/hiramaralIA/Repositorio_T_Entrega_Python/blob/main/PrimeiroProgramaPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Meu primeiro programa em Python para Lógica de Programação

# %%
print("Olá aluno Cetam! Iniciamos com Python ")
# Out:
# Olá aluno Cetam! Iniciamos com Python

# %%
2+4
# Out:
# 6

# %% [markdown]
# Primeiroa atalhos: shift + enter abre uma célula, e crtrl + enter executa
# Para deletar, edit/delete cells

# %%
print("Olá mundo!")

# %%
print(2)
# Out:
# 2

# %%
print('Olá mundo 2!')

# %% [markdown]
# # Erro comum

# %%
print(Olá mundo!)
# Out:
#   File "C:\Users\hiram\AppData\Local\Temp/ipykernel_19060/1057246432.py", line 1
#     print(Olá mundo!)
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # OPerações em Python segue, a matemática

# %%
print(1+5)
# Out:
# 6

# %%
print(1+3*3)
# Out:
# 10

# %% [markdown]
# # Strings em Python

# %%
print("Eu estudo LP no CETAM")
# Out:
# Eu estudo LP no CETAM

# %% [markdown]
# # Concatenar

# %%
print('Estou estudando ' +  'Python' )
# Out:
# Estou estudando Python

# %%
print('Estou estudando ' in 'Python' )
# Out:
# False

# %%
print('Py' in 'Python' )
# Out:
# True

# %%
print(1+8)
# Out:
# 9

# %%
print('Hiram' in 'Hiram á profesor Python' )
# Out:
# True

# %% [markdown]
# # Reiniciando o kernel

# %%
print = "texto"

# %%
print ("texto")
# Out:
# texto
