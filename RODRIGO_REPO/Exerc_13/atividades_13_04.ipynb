# %%
# Atividade dia 13/04

meta = int(input("Informe a meta: "))
qtdVendida = int(input("Informe a quantidade vendida no mês: "))

if qtdVendida < meta:
  print("Não bateu a meta!")
else:
  print("Vencemos, batemos a metaa!!!")
# Out:
# Informe a meta: 5000
# Informe a quantidade vendida no mês: 2800
# Não bateu a meta!

# %%
taxaFundo = float(input("Informe a taxa a ser pago: "))

if taxaFundo < 0.05 :
  print("O fundo ele pode cobrar taxa dos seus investidores.")
elif taxaFundo >= 0.05 and taxaFundo <= 0.2 :
  print("O fundo irá cobrar 2% de taxa dos seus investidores.")
else :
  print("O fundo irá cobrar 4% de taxa dos seus investidores.")
# Out:
# Informe a taxa a ser pago: .03
# O fundo ele pode cobrar taxa dos seus investidores.

# %%
meta = 20000
bonus = 0
qtdVendida = int(input("Informe a quantidade vendida no mês: "))

if qtdVendida < meta:
  print(" O vendedor(a) não ganha bônus.!")

elif qtdVendida > meta and qtdVendida < (meta * 2):
  bonus = (qtdVendida * 0.03)
  print(f"O vendedor(a) ganhou um bônus de, {bonus:.2f}")

elif qtdVendida >= (meta * 2):
  bonus = (qtdVendida * 0.07)
  print(f"O vendedor(a) ganhou um bônus de, {bonus:.2f}")

else:
  print("Opçaõ inválida!!!")
# Out:
# Informe a quantidade vendida no mês: 100000
# O vendedor(a) ganhou um bônus de, 7000.00 !
