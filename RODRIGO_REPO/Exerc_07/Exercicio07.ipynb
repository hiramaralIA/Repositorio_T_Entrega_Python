# %%
# Escreva um algoritmo para ler as dimensões de a hipotenusa de um triângulo. Use h**2 = a**2 + b**2

a = float(input("Informe o valor de a: "))
b = float(input("Informe o valor de b: "))
h = (a**2 + b**2) ** (1/2)

print("O valor da hipotenusa é {}".format(h))
# Out:
# Informe o valor de a: 3
# Informe o valor de b: 3
# O valor da hipotenusa é 4.242640687119285
