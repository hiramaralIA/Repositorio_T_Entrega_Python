# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtyGui/Repositorio_T_Entrega_Python/blob/main/exercicio_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
//somar 10 + 20 x 30
print(10+20 * 30)
# Out:
#   File "C:\Users\aluno22\AppData\Local\Temp/ipykernel_3700/352314613.py", line 1
#     //somar 10 + 20 x 30
#     ^
# SyntaxError: invalid syntax

# %%
#somar 10 + 20 x 30
print(10+20 * 30)
# Out:
# 610

# %%
#somar 10 + 20 x 30
#dividir 42/30
print(10+20 * 30)
print(42/30)
# Out:
# 610
# 1.4

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
# Out:
# 610
# 1.4
# 575

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
# Out:
# 610
# 1.4
# 575
# 107

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1
#subtração com resultado sendo dividido por 10 e sendo somado com 1500 e multiplicado com 9 e sendo elevado ao cubo

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
print(((1500+(100-9)/10)*9)^3)
# Out:
# 610
# 1.4
# 575
# 107
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3700/2239213273.py in <module>
#       9 print((94+2)*6-1)
#      10 print((10+8)*(10-4)-1)
# ---> 11 print(((1500+(100-9)/10)*9)^3)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1
#subtração com resultado sendo dividido por 10 e sendo somado com 1500 e multiplicado com 9 e sendo elevado ao cubo

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
print (((1500 + ((100-9)/10))*9)^3)
# Out:
# 610
# 1.4
# 575
# 107
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3700/2229218575.py in <module>
#       9 print((94+2)*6-1)
#      10 print((10+8)*(10-4)-1)
# ---> 11 print (((1500 + ((100-9)/10))*9)^3)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1
#subtração com resultado sendo dividido por 10 e sendo somado com 1500 e multiplicado com 9 e sendo elevado ao cubo

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
print(((1500+(100-9)/10)*9))^3
# Out:
# 610
# 1.4
# 575
# 107
# 13581.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3700/2554431656.py in <module>
#       9 print((94+2)*6-1)
#      10 print((10+8)*(10-4)-1)
# ---> 11 print(((1500+(100-9)/10)*9))^3
#
# TypeError: unsupported operand type(s) for ^: 'NoneType' and 'int'

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1
#subtração com resultado sendo dividido por 10 e sendo somado com 1500 e multiplicado com 9 e sendo elevado ao cubo

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
print(((1500+((100-9)/10))*9)^3)
# Out:
# 610
# 1.4
# 575
# 107
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3700/1923145023.py in <module>
#       9 print((94+2)*6-1)
#      10 print((10+8)*(10-4)-1)
# ---> 11 print(((1500+((100-9)/10))*9)^3)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
#somar 10 + 20 x 30
#dividir 42/30
#soma entre parênteses e multiplicação e depois subtração
#multiplicação entre parênteses com a subtração por 1
#subtração com resultado sendo dividido por 10 e sendo somado com 1500 e multiplicado com 9 e sendo elevado ao cubo

print(10+20 * 30)
print(42/30)
print((94+2)*6-1)
print((10+8)*(10-4)-1)
print(((1500+((100-9)/10))*9)**3)
# Out:
# 610
# 1.4
# 575
# 107
# 2505426032558.259
