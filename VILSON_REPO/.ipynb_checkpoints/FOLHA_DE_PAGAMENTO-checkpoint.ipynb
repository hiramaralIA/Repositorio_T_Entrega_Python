# %%
"""
// Função : Escrever um algoritmo para uma empresa que decide dar um
// reajuste a seus 584 funcionários de acordo com os
// seguintes critérios:
// a) 50% para aqueles que ganham menos do que três salários mínimos;
// b) 20% para aqueles que ganham entre três até dez salários mínimos;
// c) 15% para aqueles que ganham acima de dez até vinte salários mínimos;
// d) 10% para os demais funcionários.
// Leia o nome do funcionário, seu salário e o valor do salário mínimo.
// Calcule o seu novo salário reajustado. Escrever o
// nome do funcionário, o reajuste e seu novo salário. Calcule quanto à
// empresa vai aumentar sua folha de pagamento.
"""

# %%
salarioMin = float(input("Digite o valor do salario minimo hoje: \n"))

for i in range(0, 5):
    
    nome = input("Digite seu nome: \n")
    salario = float(input("Digite o valor do seu salario: \n"))

    
    if salario < salarioMin*3:
        reajuste = 50/100
        total = reajuste+(salario*reajuste)
        folha =+ salario
        salarioNovo = salario+(salario*reajuste)
        novaFolha =+ salarioNovo
        
        print(f"NOME: {nome}\n")
        print(f"REAJUSTE DE 50%: {salario*reajuste}\n")
        print(f"NOVO SALARIO COM AJUSTE: {salarioNovo}\n")
        
        
    elif salario <= salarioMin*10:
        reajuste = 20/100
        total = reajuste+(salario*reajuste)
        folha =+ salario
        salarioNovo = salario+(salario*reajuste)
        novaFolha =+ salarioNovo
        
        print(f"NOME: {nome}\n")
        print(f"REAJUSTE DE 20%: {salario*reajuste}\n")
        print(f"NOVO SALARIO COM AJUSTE: {salarioNovo}\n")
               
    elif salario <= salarioMin*20:
        reajuste = 15/100
        total = reajuste+(salario*reajuste)
        folha =+ salario
        salarioNovo = salario+(salario*reajuste)
        novaFolha =+ salarioNovo
        
        print(f"NOME: {nome}\n")
        print(f"REAJUSTE DE 15%: {salario*reajuste}\n")
        print(f"NOVO SALARIO COM AJUSTE: {salarioNovo}\n")
        
        
    else:
        reajuste = 10/100
        total = reajuste+(salario*reajuste)
        folha =+ salario
        salarioNovo = salario+(salario*reajuste)
        novaFolha =+ salarioNovo

        print(f"NOME: {nome}\n")
        print(f"REAJUSTE DE 10%: {salario*reajuste}\n")
        print(f"NOVO SALARIO COM AJUSTE: {salarioNovo}\n")
        
    print(f"Valor atual da folha: {folha} R$\n")
    print(f"Valor da nova folha: {novaFolha} R$\n")
    
    
        
print("A empresa aumentou a folha de pagamentos em: ",novaFolha - folha)
# Out:
# Digite o valor do salario minimo hoje:
# 900
# Digite seu nome:
# Vilson
# Digite o valor do seu salario:
# 5000
# NOME: Vilson
#
# REAJUSTE DE 20%: 1000.0
#
# NOVO SALARIO COM AJUSTE: 6000.0
#
# Valor atual da folha: 5000.0 R$
#
# Valor da nova folha: 6000.0 R$
#
# Digite seu nome:
# Vilson2
# Digite o valor do seu salario:
# 2000
# NOME: Vilson2
#
# REAJUSTE DE 50%: 1000.0
#
# NOVO SALARIO COM AJUSTE: 3000.0
#
# Valor atual da folha: 2000.0 R$
#
# Valor da nova folha: 3000.0 R$
#
# Digite seu nome:
# Vilson3
# Digite o valor do seu salario:
# 10000
# NOME: Vilson3
#
# REAJUSTE DE 15%: 1500.0
#
# NOVO SALARIO COM AJUSTE: 11500.0
#
# Valor atual da folha: 10000.0 R$
#
# Valor da nova folha: 11500.0 R$
#
# Digite seu nome:
# Vilson4
# Digite o valor do seu salario:
# 25000
# NOME: Vilson4
#
# REAJUSTE DE 10%: 2500.0
#
# NOVO SALARIO COM AJUSTE: 27500.0
#
# Valor atual da folha: 25000.0 R$
#
# Valor da nova folha: 27500.0 R$
#
# Digite seu nome:
# VILSON
# Digite o valor do seu salario:
# 9000
# NOME: VILSON
#
# REAJUSTE DE 20%: 1800.0
#
# NOVO SALARIO COM AJUSTE: 10800.0
#
# Valor atual da folha: 9000.0 R$
#
# Valor da nova folha: 10800.0 R$
#
# A empresa aumentou a folha de pagamentos em:  1800.0
