# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigues33/Repositorio_T_Entrega_Python/blob/main/Atividade_Python___Rodrigues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1000+1000
# Out:
# 2000

# %%
print("Olá Tudo, Tudo bem")
print("Estou estudando" + "Paython")
# Out:
# Olá Tudo, Tudo bem
# Estou estudandoPaython

# %%
print("1" in "1")
# Out:
# True

# %%
print("10" in "4")
# Out:
# False

# %%
print("A Vaneise"in"é")
# Out:
# False

# %%
print = "text"

# %%
1500 +(1500*5/100)
# Out:
# 1575.0

# %%
3%2
# Out:
# 1

# %%
10%3
# Out:
# 1

# %%
10+20*30
# Out:
# 610

# %%
42/30
# Out:
# 1.4

# %%
(94+2)*6-1
# Out:
# 575

# %%
((10+8))*((10-4))-1
# Out:
# 107

# %%
((1500+((100-9)/10))*9)
# Out:
# 13581.9

# %%
10%3*10**2+1-10*4/2
# Out:
# 81.0

# %%
a = 2 
b = 3 
print (a + b)
# Out:
# 5

# %%
salario = 1500 #(1)
aumento = 5 #(2)
print (salario +(salario*aumento/100)) #(3)
# Out:
# 1575.0

# %%
a = 2 
b = 3 
c = 5
print (a + b * c)
# Out:
# 17

# %%
salario = 750 #(1)
aumento = 15 #(2)
print (salario +(salario*aumento/100)) #(3)
# Out:
# 862.5

# %%
metros = float (input('metros?'))
cent = metros * 100;
print (cent), 'cm'
# Out:
# metros?10
# 1000.0
# (None, 'cm')
